# %%
import io

import pandas as pd
from Bio import Entrez, SeqIO
from mysql.connector import connection
from sshtunnel import SSHTunnelForwarder

# Укажите ваш email (обязательно для использования Entrez)
Entrez.email = "your.email@example.com"

# %%
with open("db_curated_server_info.txt", "r") as file:
    lines = file.readlines()

config = {}

for line in lines:
    line = line.strip()
    if line and not line.startswith("#"):
        key, value = line.split("=", 1)
        config[key] = value.strip()

server_name = config.get("server_name")
srever_port = int(config.get("srever_port"))
ssh_password = config.get("ssh_password")
ssh_username = config.get("ssh_username")
db_adress = config.get("db_adress")
db_port = int(config.get("db_port"))

# %%
tunnel = SSHTunnelForwarder(
    (server_name, srever_port),
    ssh_password=ssh_password,
    ssh_username=ssh_username,
    remote_bind_address=(db_adress, db_port),
)
tunnel.start()
print(tunnel.local_bind_port)
# Out:
# 38721

# %%
conn = connection.MySQLConnection(
    user="db_user",
    password="db_password",
    host="localhost",
    port=tunnel.local_bind_port,
    database="db_name",
)
cursor = conn.cursor()

# %%
query = "SHOW TABLES;"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('alternative_name',),
#  ('histone',),
#  ('histone_description',),
#  ('histone_has_publication',),
#  ('publication',),
#  ('sequence',),
#  ('sequence_has_publication',)]

# %%
# add_histone = (
#     "INSERT INTO histone "
#     "(id, level, taxonomic_span, taxonomic_span_id, description, parent) "
#     "VALUES (%(id)s, %(level)s, %(taxonomic_span)s, %(taxonomic_span_id)s, %(description)s, %(parent)s)"
# )
# add_histone_description = (
#     "INSERT INTO histone_description "
#     "(summary, taxonomy, genes, evolution, expression, knock_out, function, sequence, localization, deposition, structure, interactions, disease, caveats) "
#     "VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
# )
# add_publication = (
#     "INSERT INTO publication "
#     "(id, title, doi, author, year) "
#     "VALUES (%(id)s, %(title)s, %(doi)s, %(author)s, %(year)s)"
# )
# add_sequence = (
#     "INSERT INTO sequence "
#     "(accession, variant, gi, ncbi_gene_id, hgnc_gene_name, taxonomy_id, organism, phylum, class, taxonomy_group, info, sequence, variant_under_consideration) "
#     "VALUES (%(accession)s, %(variant)s, %(gi)s, %(ncbi_gene_id)s, %(hgnc_gene_name)s, %(taxonomy_id)s, %(organism)s, %(phylum)s, %(class)s, %(taxonomy_group)s, %(info)s, %(sequence)s, %(variant_under_consideration)s)"
# )
# add_sequence_has_publication = (
#     "INSERT INTO sequence_has_publication "
#     "(sequence_accession, publication_id) "
#     "VALUES (%s, %s)"
# )
# add_alternate_names = (
#     "INSERT INTO alternative_name "
#     "(name, taxonomy, gene, splice, histone) "
#     "VALUES (%(name)s, %(taxonomy)s, %(gene)s, %(splice)s, %(histone)s)"
# )
add_histone_has_publication = (
    "INSERT INTO histone_has_publication "
    "(histone_id, publication_id) "
    "VALUES (%s, %s)"
)

# %%
def get_taxonomy_data(record):
    import re
    import sys

    taxonomy_data = {}
    taxonomy_data["organism"] = record.annotations["organism"]
    try:
        for a in record.features[0].qualifiers["db_xref"]:
            text = re.search("(\S+):(\S+)", a).group(1)
            taxid = re.search("(\S+):(\S+)", a).group(2)
            if text == "taxon":
                print(f"Fetched taxid from NCBI {taxid}")
                taxonomy_data["taxonomy_id"] = int(taxid)
            else:
                continue
    except:
        print("!!!!!!Unable to get TAXID for this record setting it to 1")
        taxonomy_data["taxonomy_id"] = 1  # unable to identify

    lineage = dict()
    for i in range(10):
        try:
            handle = Entrez.efetch(
                id=taxonomy_data["taxonomy_id"], db="taxonomy", retmode="xml"
            )
            tax_data = Entrez.read(handle)
            lineage = {
                d["Rank"]: d["ScientificName"]
                for d in tax_data[0]["LineageEx"]
                if d["Rank"] in ["class", "phylum"]
            }
            break
        except:
            print(
                "Unexpected error: {}, Retrying, attempt {}".format(
                    sys.exc_info()[0], i
                )
            )
            if i == 9:
                print(
                    f"FATAL ERROR could not get class and phylum from NCBI after 10 attempts for taxid:{taxonomy_data['taxonomy_id']}. Will add None for class and phylum!"
                )
            else:
                continue
    taxonomy_data["phylum"] = lineage.get("phylum", None)
    taxonomy_data["class"] = lineage.get("class", None)
    if taxonomy_data["phylum"] is not None:
        taxonomy_data["phylum"] = str(taxonomy_data["phylum"])
    if taxonomy_data["class"] is not None:
        taxonomy_data["class"] = str(taxonomy_data["class"])
    return taxonomy_data

# %% [markdown]
# # To Do
#
# ## <span style="color:black">Add publicationes for added histone nodes</span>

# %% [markdown]
# # <span style="color:black">Add publicationes for added histone nodes</span>
#
# **New *Drosophilidae* nodes:** cenH3.1_(Drosophilidae), cenH3.2_(Drosophila_eugracilis), cenH3.3_(Montium), cenH3.4_(Montium), cenH3.5_(Drosophila), cenH3.6_(Repleta)
#
# **Publications:** kursel_recurrent_2017, kursel_gametic_2021, teixeira_concurrent_2018
#
# **New *Culicidae* nodes:** cenH3.1_(Culicidae), cenH3.2_(Culicidae), cenH3.3_(Aedes)
#
# **Publications:** kursel_ancient_2020

# %% [markdown]
# ### Add Drosophilidae histones publications
#
# **New *Drosophilidae* nodes:** cenH3.1_(Drosophilidae), cenH3.2_(Drosophila_eugracilis), cenH3.3_(Montium), cenH3.4_(Montium), cenH3.5_(Drosophila), cenH3.6_(Repleta)
#
# **Publications:** kursel_recurrent_2017, kursel_gametic_2021, teixeira_concurrent_2018

# %%
pids = ["kursel_recurrent_2017", "kursel_gametic_2021", "teixeira_concurrent_2018"]
query = f"SELECT * FROM publication"
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df[df["id"].isin(pids)]
# Out:
#                            id title   doi author  year pubmed_id
# 118       kursel_gametic_2021  None  None   None  None      None
# 119     kursel_recurrent_2017  None  None   None  None      None
# 173  teixeira_concurrent_2018  None  None   None  None      None

# %%
variants = [
    "cenH3.1_(Drosophilidae)",
    "cenH3.2_(Drosophila_eugracilis)",
    "cenH3.3_(Montium)",
    "cenH3.4_(Montium)",
    "cenH3.5_(Drosophila)",
    "cenH3.6_(Repleta)",
]

# %%
query = (
    "SELECT * FROM histone h LEFT JOIN histone_has_publication hp "
    "ON h.id = hp.histone_id "
)
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df[df["id"].isin(variants)]
# Out:
#                                  id    level         taxonomic_span  \
# 6           cenH3.1_(Drosophilidae)  variant          Drosophilidae
# 10  cenH3.2_(Drosophila_eugracilis)  variant  Drosophila eugracilis
# 14                cenH3.3_(Montium)  variant       montium subgroup
# 15                cenH3.4_(Montium)  variant       montium subgroup
# 16             cenH3.5_(Drosophila)  variant             Drosophila
# 17                cenH3.6_(Repleta)  variant          repleta group
#
#    taxonomic_span_id  description                 parent histone_id  \
# 6               7214        240.0  cenH3_(Drosophilidae)       None
# 10             29029        241.0  cenH3_(Drosophilidae)       None
# 14             32352        242.0  cenH3_(Drosophilidae)       None
# 15             32352        243.0  cenH3_(Drosophilidae)       None
# 16             32281        244.0  cenH3_(Drosophilidae)       None
# 17             32321        245.0  cenH3_(Drosophilidae)       None
#
#    publication_id
# 6            None
# 10           None
# 14           None
# 15           None
# 16           None
# 17           None

# %%
for v in variants:
    for pid in pids:
        cursor.execute(add_histone_has_publication, (v, pid))

# %%
query = (
    "SELECT * FROM histone h LEFT JOIN histone_has_publication hp "
    "ON h.id = hp.histone_id "
)
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df[df["id"].isin(variants)]
# Out:
#                                  id    level         taxonomic_span  \
# 6           cenH3.1_(Drosophilidae)  variant          Drosophilidae
# 7           cenH3.1_(Drosophilidae)  variant          Drosophilidae
# 8           cenH3.1_(Drosophilidae)  variant          Drosophilidae
# 12  cenH3.2_(Drosophila_eugracilis)  variant  Drosophila eugracilis
# 13  cenH3.2_(Drosophila_eugracilis)  variant  Drosophila eugracilis
# 14  cenH3.2_(Drosophila_eugracilis)  variant  Drosophila eugracilis
# 18                cenH3.3_(Montium)  variant       montium subgroup
# 19                cenH3.3_(Montium)  variant       montium subgroup
# 20                cenH3.3_(Montium)  variant       montium subgroup
# 21                cenH3.4_(Montium)  variant       montium subgroup
# 22                cenH3.4_(Montium)  variant       montium subgroup
# 23                cenH3.4_(Montium)  variant       montium subgroup
# 24             cenH3.5_(Drosophila)  variant             Drosophila
# 25             cenH3.5_(Drosophila)  variant             Drosophila
# 26             cenH3.5_(Drosophila)  variant             Drosophila
# 27                cenH3.6_(Repleta)  variant          repleta group
# 28                cenH3.6_(Repleta)  variant          repleta group
# 29                cenH3.6_(Repleta)  variant          repleta group
#
#    taxonomic_span_id  description                 parent  \
# 6               7214        240.0  cenH3_(Drosophilidae)
# 7               7214        240.0  cenH3_(Drosophilidae)
# 8               7214        240.0  cenH3_(Drosophilidae)
# 12             29029        241.0  cenH3_(Drosophilidae)
# 13             29029        241.0  cenH3_(Drosophilidae)
# 14             29029        241.0  cenH3_(Drosophilidae)
# 18             32352        242.0  cenH3_(Drosophilidae)
# 19             32352        242.0  cenH3_(Drosophilidae)
# 20             32352        242.0  cenH3_(Drosophilidae)
# 21             32352        243.0  cenH3_(Drosophilidae)
# 22             32352        243.0  cenH3_(Drosophilidae)
# 23             32352        243.0  cenH3_(Drosophilidae)
# 24             32281        244.0  cenH3_(Drosophilidae)
# 25             32281        244.0  cenH3_(Drosophilidae)
# 26             32281        244.0  cenH3_(Drosophilidae)
# 27             32321        245.0  cenH3_(Drosophilidae)
# 28             32321        245.0  cenH3_(Drosophilidae)
# 29             32321        245.0  cenH3_(Drosophilidae)
#
#                          histone_id            publication_id
# 6           cenH3.1_(Drosophilidae)       kursel_gametic_2021
# 7           cenH3.1_(Drosophilidae)     kursel_recurrent_2017
# 8           cenH3.1_(Drosophilidae)  teixeira_concurrent_2018
# 12  cenH3.2_(Drosophila_eugracilis)       kursel_gametic_2021
# 13  cenH3.2_(Drosophila_eugracilis)     kursel_recurrent_2017
# 14  cenH3.2_(Drosophila_eugracilis)  teixeira_concurrent_2018
# 18                cenH3.3_(Montium)       kursel_gametic_2021
# 19                cenH3.3_(Montium)     kursel_recurrent_2017
# 20                cenH3.3_(Montium)  teixeira_concurrent_2018
# 21                cenH3.4_(Montium)       kursel_gametic_2021
# 22                cenH3.4_(Montium)     kursel_recurrent_2017
# 23                cenH3.4_(Montium)  teixeira_concurrent_2018
# 24             cenH3.5_(Drosophila)       kursel_gametic_2021
# 25             cenH3.5_(Drosophila)     kursel_recurrent_2017
# 26             cenH3.5_(Drosophila)  teixeira_concurrent_2018
# 27                cenH3.6_(Repleta)       kursel_gametic_2021
# 28                cenH3.6_(Repleta)     kursel_recurrent_2017
# 29                cenH3.6_(Repleta)  teixeira_concurrent_2018

# %%
df[df["id"].isin(variants)]["publication_id"].value_counts()
# Out:
# publication_id
# kursel_gametic_2021         6
# kursel_recurrent_2017       6
# teixeira_concurrent_2018    6
# Name: count, dtype: int64

# %%
# Make sure data is committed to the database
conn.commit()

# %% [markdown]
# ### Add Culicidae histones publications
#
# **New *Culicidae* nodes:** cenH3.1_(Culicidae), cenH3.2_(Culicidae), cenH3.3_(Aedes)
#
# **Publications:** kursel_ancient_2020

# %%
pids = ["kursel_ancient_2020"]
query = f"SELECT * FROM publication"
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df[df["id"].isin(pids)]
# Out:
#                       id title   doi author  year pubmed_id
# 117  kursel_ancient_2020  None  None   None  None      None

# %%
variants = ["cenH3.1_(Culicidae)", "cenH3.2_(Culicidae)", "cenH3.3_(Aedes)"]

# %%
query = (
    "SELECT * FROM histone h LEFT JOIN histone_has_publication hp "
    "ON h.id = hp.histone_id "
)
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df[df["id"].isin(variants)]
# Out:
#                      id    level taxonomic_span taxonomic_span_id  \
# 5   cenH3.1_(Culicidae)  variant      Culicidae              7157
# 11  cenH3.2_(Culicidae)  variant      Culicidae              7157
# 17      cenH3.3_(Aedes)  variant          Aedes              7158
#
#     description             parent histone_id publication_id
# 5         246.0  cenH3_(Culicidae)       None           None
# 11        247.0  cenH3_(Culicidae)       None           None
# 17        248.0  cenH3_(Culicidae)       None           None

# %%
for v in variants:
    for pid in pids:
        cursor.execute(add_histone_has_publication, (v, pid))

# %%
query = (
    "SELECT * FROM histone h LEFT JOIN histone_has_publication hp "
    "ON h.id = hp.histone_id "
)
cursor.execute(query)
df = pd.DataFrame(cursor.fetchall(), columns=[i[0] for i in cursor.description])
df[df["id"].isin(variants)]
# Out:
#                      id    level taxonomic_span taxonomic_span_id  \
# 5   cenH3.1_(Culicidae)  variant      Culicidae              7157
# 11  cenH3.2_(Culicidae)  variant      Culicidae              7157
# 17      cenH3.3_(Aedes)  variant          Aedes              7158
#
#     description             parent           histone_id       publication_id
# 5         246.0  cenH3_(Culicidae)  cenH3.1_(Culicidae)  kursel_ancient_2020
# 11        247.0  cenH3_(Culicidae)  cenH3.2_(Culicidae)  kursel_ancient_2020
# 17        248.0  cenH3_(Culicidae)      cenH3.3_(Aedes)  kursel_ancient_2020

# %%
df[df["id"].isin(variants)]["publication_id"].value_counts()
# Out:
# publication_id
# kursel_ancient_2020    3
# Name: count, dtype: int64

# %%
# Make sure data is committed to the database
conn.commit()

# %% [markdown]
# # Close connections

# %%
cursor.close()
conn.close()
tunnel.stop()
